# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fish=pd.read_csv('fish.csv')
fish
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
fish.shape
# Out:
# (159, 7)

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
fish.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
fish.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
fish.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
fish.nunique()
# Out:
# Species      7
# Weight     101
# Length1    116
# Length2     93
# Length3    124
# Height     154
# Width      152
# dtype: int64

# %%
fish.Species.unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
fish.Species.value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
sns.countplot('Species',data=fish)
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(fish)
plt.show()

# %%
fish.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
sns.heatmap(fish.corr(),annot=True)
plt.show()

# %%
plt.boxplot(fish['Weight'])
plt.show()

# %%
fish_wt=fish['Weight']
q3=fish_wt.quantile(0.75)
q1=fish_wt.quantile(0.25)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)

# %%
wt_outliers=fish_wt[(fish_wt<lower_limit)|(fish_wt>upper_limit)]
wt_outliers
# Out:
# 142    1600.0
# 143    1550.0
# 144    1650.0
# Name: Weight, dtype: float64

# %%
sns.boxplot(fish['Length1'])
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fish_l1=fish['Length1']
q3=fish_l1.quantile(0.75)
q1=fish_l1.quantile(0.25)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)

# %%
len1_outliers=fish_l1[(fish_l1<lower_limit)|(fish_l1>upper_limit)]
len1_outliers
# Out:
# 142    56.0
# 143    56.0
# 144    59.0
# Name: Length1, dtype: float64

# %%
sns.boxplot(fish['Length2'])
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fish_l2=fish['Length2']
q3=fish_l2.quantile(0.75)
q1=fish_l2.quantile(0.25)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)

# %%
len2_outliers=fish_l2[(fish_l2<lower_limit)|(fish_l2>upper_limit)]
len2_outliers
# Out:
# 142    60.0
# 143    60.0
# 144    63.4
# Name: Length2, dtype: float64

# %%
sns.boxplot(fish['Length3'])
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fish_l3=fish['Length3']
q3=fish_l3.quantile(0.75)
q1=fish_l3.quantile(0.25)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)

# %%
len3_outliers=fish_l3[(fish_l3<lower_limit)|(fish_l3>upper_limit)]
len3_outliers
# Out:
# 144    68.0
# Name: Length3, dtype: float64

# %%
sns.boxplot(fish['Height'])
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(fish['Width'])
plt.show()
# Out:
# C:\Users\Deepansh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fish[142:145]
# Out:
#     Species  Weight  Length1  Length2  Length3  Height  Width
# 142    Pike  1600.0     56.0     60.0     64.0   9.600  6.144
# 143    Pike  1550.0     56.0     60.0     64.0   9.600  6.144
# 144    Pike  1650.0     59.0     63.4     68.0  10.812  7.480

# %%
fish_new=fish.drop([142,143,144])

# %%
fish_new.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaling_columns=['Weight','Length1','Length2','Length3','Height','Width']
fish_new[scaling_columns]=scaler.fit_transform(fish_new[scaling_columns])
fish_new.describe()
# Out:
#              Weight       Length1       Length2       Length3        Height  \
# count  1.560000e+02  1.560000e+02  1.560000e+02  1.560000e+02  1.560000e+02
# mean  -1.665335e-16  5.551115e-17 -5.394545e-16 -2.135044e-16  9.963540e-17
# std    1.003221e+00  1.003221e+00  1.003221e+00  1.003221e+00  1.003221e+00
# min   -1.177998e+00 -1.997257e+00 -1.986079e+00 -2.042126e+00 -1.675635e+00
# 25%   -8.012570e-01 -7.321794e-01 -6.952556e-01 -7.078263e-01 -7.004973e-01
# 50%   -3.271912e-01 -7.213903e-02 -1.061895e-01 -1.239237e-01 -3.023653e-01
# 75%    7.449512e-01  7.116589e-01  7.389923e-01  8.304874e-01  7.951438e-01
# max    2.746388e+00  2.898043e+00  2.890364e+00  2.732275e+00  2.321310e+00
#
#               Width
# count  1.560000e+02
# mean   1.138690e-16
# std    1.003221e+00
# min   -1.996688e+00
# 25%   -6.036162e-01
# 50%   -7.944425e-02
# 75%    6.291357e-01
# max    2.259561e+00

# %%
data_cleaned=fish_new.drop('Weight',axis=1)
y=fish_new['Weight']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(data_cleaned,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
x_train['Species']=label_encoder.fit_transform(x_train['Species'].values)
x_test['Species']=label_encoder.transform(x_test['Species'].values)

# %%
from itertools import combinations
from hyperopt import hp
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
def evaluation_model(pred,y_val):
    score_MSE=round(mean_squared_error(pred,y_val),2)
    score_MAE=round(mean_absolute_error(pred,y_val),2)
    score_r2score=round(r2_score(pred,y_val),2)
    return score_MSE,score_MAE,score_r2score

# %%
def models_score(model_name,train_data,y_train,val_data,y_val):
    model_list=['Decision_Tree','Random_Forest','XGBoost_Regressor']
    #model1
    if model_name=='Decision_Tree':
        reg=DecisionTreeRegressor(random_state=42)
    #model2
    elif model_name=='Random_Forest':
        reg=RandomForestRegressor(random_state=42)
    #model3
    elif model_name=='XGBoost_Regressor':
        reg=xgb.XGBRegressor(objective='reg:squarederror',random_state=42)
    else:
        print('Please enter correct regressor name')
        
    if model_name in model_list:
        reg.fit(train_data,y_train)
        pred=reg.predict(val_data)
        
        score_MSE,score_MAE,score_r2score=evaluation_model(pred,y_val)
        return round(score_MSE,2),round(score_MAE,2),round(score_r2score,2)

# %%
model_list=['Decision_Tree','Random_Forest','XGBoost_Regressor']
result_scores=[]
for model in model_list:
    score=models_score(model,x_train,y_train,x_test,y_test)
    result_scores.append((model,score[0],score[1],score[2]))
    print(model,score)
# Out:
# Decision_Tree (0.05, 0.16, 0.94)
# Random_Forest (0.03, 0.11, 0.97)
# XGBoost_Regressor (0.04, 0.14, 0.96)

# %%
df_results_score=pd.DataFrame(result_scores,columns=['model','mse','mae','r2score'])
df_results_score
# Out:
#                model   mse   mae  r2score
# 0      Decision_Tree  0.05  0.16     0.94
# 1      Random_Forest  0.03  0.11     0.97
# 2  XGBoost_Regressor  0.04  0.14     0.96
